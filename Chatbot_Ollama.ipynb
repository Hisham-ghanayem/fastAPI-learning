# %% [markdown]
# <a href="https://colab.research.google.com/github/Hisham-ghanayem/fastAPI-learning/blob/main/Chatbot_Ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fname = input("What is your first name? ")
lname = input("What is ypur last name? ")
print("First name first: ",fname, lname);
print("Last name first: ", lname, ", ", fname);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1986/1062195789.py in <cell line: 0>()
# ----> 1 fname = input("What is your first name? ")
#       2 lname = input("What is ypur last name? ")
#       3 print("First name first: ",fname, lname);
#       4 print("Last name first: ", lname, ", ", fname);
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
import Ollama

history = []
model = "phi3:mini"
prompt = input('')
message = {
    role: 'Hihsam',
    content: promot
}
history.append(message)
print()
Assistant_Respond = ''
response = Ollama.model.content
for chunck in response:
    Assistant_Respond += chunck
    print(Assistant_Respond, end='', stream = true)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_215/3618485459.py in <cell line: 0>()
# ----> 1 import Ollama
#       2 pass
#       3 history = []
#       4 model = "gemma3:mini"
#       5 prompt = input('')
#
# ModuleNotFoundError: No module named 'Ollama'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from ollama import chat
history = []
model = 'phi3:mini'

def get_input():
  return(input'Hisham: ')

def get_user_input(prompt, history):
  history.append[
      {
          'role': 'user',
          'content': prompt
      }
  ]
def get_model(model, history):
  response = chat(model=model, messages=history)
  return response.message.content

def get_model_message(history, assistant_response):
  history.append({
      'role': 'assistant',
      'content': assistant_response
  })

 def print_reply(assistant_response):
  print(f'Assistant: {assistant_response}')


while True:
  prompt = get_input()
  if prompt.lower() in ['exit', 'bye']:
    break


get_user_input(prompt, history)
assistant_response = get_model(model, history)
print_reply(assistant_response)

get_model_message(history, assistant_response)

# %%
from ollama import chat
history = []
model = 'phi3:mini'

def get_user_input():
  prompt = input('Hisham: ')
  return prompt

def add_user_input(message, history):
  history.append( messages= ({
      'role' : 'user',
      'content' : prompt
  }))

def get_model_response(model, history):
  response = chat(model=mode,message=message)
  return response.message.content

def get_assistant_response(history, assistant_response):
  history.append(message =({
      'role': 'assistant',
      'content': assistant
      }))
  return assistant_response

def print_reply(assistant_response):
  print(f'Assistant: {assistant_response}')

  while True:
    if input.lower() in ['exit','bye']:
      break

get_user_input()
add_user_input(prompt, history)
assistant_response = get_model_response(model, history)
get_assistant_response(history, assistant_response)
print_reply(assistant_response)
# Out:
#   File "/tmp/ipykernel_574/2735563950.py", line 22
#     'content': assistant
#                         ^
# SyntaxError: incomplete input

# %%
def get_response(user_input):
  lowered_input = user_input.lower()
  if 'hello' in lowered_input:
    return "hello there"
  elif 'how are you' in lowered_input:
    return "I am fine, thank you"
  elif 'bye' in lowered_input:
    return "take care"
  else:
    return "I am a simple chatbot"
while True:
  user_input = input("you: ")
  if user_input.lower() == 'exit':
    print("chatbot: bye")
    break
  response = get_response(user_input)
  print(f"chatbot: {response}")
# Out:
# you: asdsadas
# chatbot: I am a simple chatbot
# you: hello
# chatbot: hello there
